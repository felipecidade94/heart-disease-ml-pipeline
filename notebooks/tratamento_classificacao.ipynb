# %%
import pandas as pd
import numpy as np

# %%
# Lê o arquivo
df = pd.read_csv('../data/csv/heart.csv', sep = ',', encoding = 'iso-8859-1')

# %%
# Mostra as 5 primeiras linhas
df.head()

# %%
# Mostra as 5 últimas linhas
df.tail()

# %%
# Número de linhas e colunas
n_lin_col = df.shape
print(f'{n_lin_col[0]} linhas e {n_lin_col[1]} colunas')

# %% [markdown]
# ### Análise das variáveis (Atributos)

# %% [markdown]
# ##### Age (idade)

# %%
df['Age'].value_counts()

# %%
df['Age'].value_counts().sort_index()

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook'

# %%
hist1 = px.histogram(df, x = 'Age',nbins=60)
hist1.update_layout(width=800, height=500, title_text='Distribuição por idade')
hist1.show()
